# %% [markdown]
# UNICARIOCA - PÓS GRADUAÇÃO EM CIÊNCIA DE DADOS
#
# ESTATÍSTICA APLICADA A NEGÓCIOS - AMOSTRAGEM - aula_02_AMT_02
#
# Manuel Martins

# %%
#!pip install openpyxl --upgrade
#!pip install pandas --upgrade
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed
from numpy.random import normal

# %%
#===================================
#  DADOS PARA GERAÇÃO DA AMOSTRA
#===================================
n = 100   # tamanho da amostra
media = 5 # media populacional
dp = 2    # desvio padrão populacional
plt.figure(figsize=(20,20))

# %%
#==============================================================================================================
x = np.random.normal(media, dp, n)          # Gera uma amostra com distribuição normal (media, dp e tamanho n) 
#==============================================================================================================
print(x)
dados=x
print(x.mean(),dados.mean())
print(x.std(),dados.std())
dados.mean()
# Out:
# [ 3.56006433  4.70862206  6.17607397  6.74108076  4.33343022  4.28747702
#   5.32473696  7.21642429  6.56991936  8.31338272  4.28985454  6.43890558
#   4.96481104  5.02268563  3.05677932  3.43430293  5.40428288  4.25525556
#   6.01378796  7.39527913  5.05031963  5.22725504  1.99726459  6.71742223
#  10.17954988  5.48683104  5.13515507  6.23924376  7.971982    9.97568354
#   5.10950723  3.68869267  2.32541265  5.62381461  3.20317406  4.99421545
#   7.45611666  5.17920272  5.94610668  4.16714118  2.78065417  4.09201674
#   7.52736534  7.58432657  3.52673129  5.27875507  6.78301572  7.68605357
#   4.75442743  6.0745487   5.69495957  6.86197722  5.76070111  4.73774738
#   5.92594285  4.38534724 10.42923687  4.8570017   2.30311328  2.80103573
#   6.85954058 10.26716561  5.5935526   3.94571642  5.16345469  3.0393081
#   2.94760869  4.31707544  1.29521473  3.85971661  5.62585232  2.26406935
#   3.93052362  5.09621342  4.58528159  5.83702088  3.08082104  5.07747401
#   7.03008008  5.9908462   5.11539146  3.80736823  6.5948978   5.73545119
#   7.47202115  5.46173771  6.94311008  6.1552914   2.97986793  4.79207056
#   6.1561622   5.86230327  7.0525887   5.1756776   5.72592811  8.46719627
#   3.39006312  6.56068019  6.77077388  6.22273432]
# 5.412740556793327 5.412740556793327
# 1.7979974346057694 1.7979974346057694
# 5.412740556793327

# %%
#seed(1)                                      # ALTERNATIVA PARA GERAR UMA AMOSTRA #
#dados = normal(loc=media, scale=dp, size=n)  # Gera uma distribuição normal (media,dp,tamanho n)
#print("dados: {}".format(dados))
#dados.mean()
#dados.std()

# %%
from scipy import stats
import math

# %% [markdown]
# CÁLCULO DAS ESTATÍSTICAS DA AMOSTRA

# %%
media = dados.mean()
dp=dados.std()
var=dados.var()
minimo = dados.min()
maximo = dados.max()
mediana = np.median(dados)   
moda = stats.mode(dados)

# %% [markdown]
# IMPRESSÃO ESTATÍSTICAS DA AMOSTRA

# %%
print("media:{:.4f}".format(media))
print("desvio padrão:{:.4f}".format(dp))
print("variância:{:.4f}".format(var))
print("mínimo:{:.4f}".format(minimo))
print("máximo:{:.4f}".format(maximo))
print("mediana:{:.4f}".format(mediana))
print("moda:{}; quantidade:{}".format(moda.mode,moda.count))
# Out:
# media:5.4127
# desvio padrão:1.7980
# variância:3.2328
# mínimo:1.2952
# máximo:10.4292
# mediana:5.3017
# moda:[1.29521473]; quantidade:[1]

# %% [markdown]
# VALORES DE X PARA O GRÁFICO

# %%
x = np.linspace(media - 3*dp, media + 3*dp, 100)  # CRIA 100 VALORES PARA X ENTRE OS LIMITES 
print(x)
vetx=stats.norm.pdf(x,media,dp)                   # VALORES DA FUNÇÃO DISTRIBUIÇÀO PARA X 
print(vetx)
# Out:
# [ 0.01874825  0.12771779  0.23668734  0.34565688  0.45462642  0.56359596
#   0.6725655   0.78153504  0.89050458  0.99947413  1.10844367  1.21741321
#   1.32638275  1.43535229  1.54432183  1.65329138  1.76226092  1.87123046
#   1.9802      2.08916954  2.19813908  2.30710862  2.41607817  2.52504771
#   2.63401725  2.74298679  2.85195633  2.96092587  3.06989541  3.17886496
#   3.2878345   3.39680404  3.50577358  3.61474312  3.72371266  3.83268221
#   3.94165175  4.05062129  4.15959083  4.26856037  4.37752991  4.48649945
#   4.595469    4.70443854  4.81340808  4.92237762  5.03134716  5.1403167
#   5.24928624  5.35825579  5.46722533  5.57619487  5.68516441  5.79413395
#   5.90310349  6.01207303  6.12104258  6.23001212  6.33898166  6.4479512
#   6.55692074  6.66589028  6.77485983  6.88382937  6.99279891  7.10176845
#   7.21073799  7.31970753  7.42867707  7.53764662  7.64661616  7.7555857
#   7.86455524  7.97352478  8.08249432  8.19146386  8.30043341  8.40940295
#   8.51837249  8.62734203  8.73631157  8.84528111  8.95425066  9.0632202
#   9.17218974  9.28115928  9.39012882  9.49909836  9.6080679   9.71703745
#   9.82600699  9.93497653 10.04394607 10.15291561 10.26188515 10.37085469
#  10.47982424 10.58879378 10.69776332 10.80673286]
# [0.00246488 0.00295094 0.0035199  0.00418317 0.00495319 0.00584344
#  0.00686844 0.00804362 0.00938535 0.01091073 0.01263752 0.01458394
#  0.01676844 0.01920946 0.02192515 0.02493301 0.02824956 0.03188993
#  0.03586741 0.04019309 0.04487532 0.0499193  0.05532663 0.06109487
#  0.06721715 0.07368179 0.08047206 0.08756586 0.09493565 0.10254833
#  0.11036534 0.11834273 0.1264315  0.1345779  0.14272401 0.15080825
#  0.15876617 0.16653121 0.1740356  0.18121133 0.18799114 0.19430959
#  0.20010404 0.20531577 0.20989086 0.21378122 0.21694536 0.21934916
#  0.22096648 0.2217796  0.2217796  0.22096648 0.21934916 0.21694536
#  0.21378122 0.20989086 0.20531577 0.20010404 0.19430959 0.18799114
#  0.18121133 0.1740356  0.16653121 0.15876617 0.15080825 0.14272401
#  0.1345779  0.1264315  0.11834273 0.11036534 0.10254833 0.09493565
#  0.08756586 0.08047206 0.07368179 0.06721715 0.06109487 0.05532663
#  0.0499193  0.04487532 0.04019309 0.03586741 0.03188993 0.02824956
#  0.02493301 0.02192515 0.01920946 0.01676844 0.01458394 0.01263752
#  0.01091073 0.00938535 0.00804362 0.00686844 0.00584344 0.00495319
#  0.00418317 0.0035199  0.00295094 0.00246488]

# %% [markdown]
# FONTES

# %%
font1 = {'family':'serif','color':'blue','size':12}
font2 = {'family':'serif','color':'darkred','size':15}

# %% [markdown]
# IMPRESSÃO DOS GRÁFICOS

# %%
plt.xlabel("Valores de x", fontdict = font1)
plt.ylabel("Probbilidade", fontdict = font1)
#plt.plot(vetx)
#plt.plot(stats.norm.pdf(x,media,dp)) 
plt.plot(x, stats.norm.pdf(x,media,dp))

# %% [markdown]
# plot(x, y)        # plot x and y using default line style and color
#
# plot(x, y, 'bo')  # plot x and y using blue circle markers
#
# plot(y)           # plot y using x as index array 0..N-1
#
# plot(y, 'r+')     # ditto, but with red plusses
#
# [MATPLOTLIB_MANUAL](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html)

# %% [markdown]
# CÁLCULO DA VARIÁVEL TRANSFORMADA    z = (x-médiax)dpx

# %%
# ------------------------------------------------------------------------------------------
# CÁLCULO DA VARIÁVEL TRANSFORMADA Z = (X - MEDIAX) / DPX - NORMAL PADRÃO MÉDIA=0 VAR/DP=1
# ------------------------------------------------------------------------------------------
z=(dados-media)/dp   # No nosso exemplo X = DADOS
print(z)
mediaz=z.mean()
varz=z.var()
# Out:
# [-1.03041094 -0.39161262  0.42454644  0.73878871 -0.60028469 -0.62584268
#  -0.04894534  1.00316257  0.64359313  1.61326268 -0.62452037  0.57072663
#  -0.2491269  -0.21693854 -1.31032514 -1.1003562  -0.00470394 -0.64376343
#   0.33428713  1.10263704 -0.20156921 -0.10316228 -1.89960002  0.72563044
#   2.65117693  0.04120723 -0.15438592  0.45967986  1.42338437  2.53779171
#  -0.16865059 -0.95887116 -1.7170925   0.11739397 -1.22890414 -0.23277292
#   1.13647331 -0.12988775  0.29664454 -0.69277038 -1.46389885 -0.73455267
#   1.1761      1.20778037 -1.04894992 -0.07451929  0.76211186  1.26435832
#  -0.36613686  0.3680807   0.15696297  0.80602822  0.19352673 -0.37541387
#   0.28542993 -0.57140978  2.79004642 -0.30908768 -1.72949483 -1.45256315
#   0.80467302  2.69990655  0.10056302 -0.81592115 -0.1386464  -1.32004218
#  -1.37104304 -0.6093808  -2.29006213 -0.86375203  0.11852729 -1.75121007
#  -0.82437099 -0.17604427 -0.46021143  0.23597382 -1.29695375 -0.18646664
#   0.89952271  0.32152751 -0.16537793 -0.89286686  0.6574855   0.17948337
#   1.14531898  0.02725096  0.85115223  0.41298771 -1.35310128 -0.34520072
#   0.41347203  0.25003524  0.91204143 -0.13184833  0.17418688  1.69880983
#  -1.12496125  0.63845454  0.75530326  0.45049773]

# %%
# ESTATÍSTICAS DE Z (NORMAL PADRÃO) - IMPRESSÃO - GRÁFICO
print("mediaz: {:.4f}".format(mediaz))
print("varz: {:.4f}".format(varz))
dpz = math.sqrt(varz)
print("dpz: {:.4f}".format(dpz))
plt.plot(z,)
# Out:
# mediaz: -0.0000
# varz: 1.0000
# dpz: 1.0000

# %% [markdown]
# GRÁFICO DE Z - FUNÇÃO DENSIDADE

# %%
z = np.linspace(mediaz - 3*dpz, mediaz + 3*dpz, 100)
plt.xlabel("Valores de z", fontdict = font1)
plt.ylabel("Probbilidade", fontdict = font1)
plt.title('Normal Padrão')            
plt.plot(z, stats.norm.pdf(z,mediaz,dpz))
plt.show()

# %% [markdown]
# ALGUMAS ROTINAS GRÁFICAS E MANUAIS

# %%
# ROTINAS GRÁFICAS
import matplotlib.pyplot as plt

# %% [markdown]
# [NUMPY.LINSPACE_MANUAL]( https://numpy.org/doc/stable/reference/generated/numpy.linspace.html)

# %% [markdown]
# [NUMPY.ZEROS_MANUAL](https://numpy.org/doc/stable/reference/generated/numpy.zeros.html)

# %% [markdown]
# [MATPLOTLIB_INFINITE_LINES](https://matplotlib.org/stable/gallery/pyplots/axline.html#sphx-glr-gallery-pyplots-axline-py)

# %%
n = 8
y = np.zeros(n)
print(y)
x1 = np.linspace(0, 10, n, endpoint=False)
print(x1)
plt.plot(x1, y, 'o')
[<matplotlib.lines.Line2D object at 0x...>]

plt.plot(x1, y + 0.5, 'o')
[<matplotlib.lines.Line2D object at 0x...>]

plt.ylim([-0.5, 1])
(-0.5, 1)
plt.ylim([0, 100])
plt.xlim([1, 10])
y=x**2
plt.plot(x,y,"o")
# Out:
# (-0.5, 1.0)

# %% [markdown]
# ### FUNÇÕES PARA CÁLCULO DE PROBABILIDADE E QUANTIS

# %%
#---------------------------------------------------------
# FUNÇÕES PARA CÁLCULO DE PROBABILIDADE E QUANTIS
#---------------------------------------------------------
from scipy.stats import norm
#print(norm.cdf(norm.ppf(0.25))) 
#print(norm.ppf(norm.cdf(0.25)))

# %%
norm.cdf(0)           # RECEBE QUANTIL DEVOLVE PROBABILIDADE ATÉ O QUANTIL
norm.cdf(0,0,1)       # (quantil,média,dp)

norm.ppf(0.25)        # RECEBE PROBABILIDADE DEVOLVE QUANTIL
norm.ppf(0.25,0,1)    # (probabilidade,média,dp)

# %%
norm.sf(1)            # RECEBE QUANTIL DEVOLVE PROBABILIDADE  SF = 1 - CDF 
norm.sf(0,0,1)        # (quantil,média,dp)

norm.sf(2)            # DEVOLVE PROBABILIDADE ACIMA DE X
1-norm.cdf(2)           # DEVOLVE PROBABILIDADE ATÉ X
norm.cdf(-1)
1-norm.cdf(1)

norm.cdf(1)-norm.cdf(-1)  # 68% das Observações estão entre (média + 1DP) e (média - 1DP)  
#d = norm.sf(1)
#print(d)
#print("q1:{:.1f}".format(norm.ppf(d)))  # RECEBE PROBABILIDADE DEVOLVE QUANTIL

norm.ppf(norm.cdf(0.25))         # RECEBE PROBABILIDADE DEVOLVE QUANTIL

# %%
norm.sf(1)            # DEVOLVE PROBABILIDADE ACIMA DE X
norm.cdf(1)           # DEVOLVE PROBABILIDADE ATÉ X

norm.sf(1)+norm.cdf(1)

# %% [markdown]
# EXERCÍCIOS DO MATERIAL TEÓRICO RESOLVIDOS EM PYTHON
# *  **EST_APLIC_NEG_AULA_02_A.pdf**

# %%
#---------------------------------------------------------
# FUNÇÕES PARA CÁLCULO DE PROBABILIDADE E QUANTIS
#---------------------------------------------------------
from scipy.stats import norm

# %% [markdown]
# Exemplo-01: Seja X a variável aleatória que representa os diâmetros de parafusos produzidos por determinada máquina. Suponha que essa variável tenha distribuição normal com média =2,0 cm e desvio padrão = 0,04 cm.
#
# *   a) um parafuso produzido pela máquina ter um diâmetro maior que 2,0 cm.
# *   b) um parafuso produzido pela máquina ter um diâmetro maior do que 2,04 cm.
# *   c) um parafuso produzido pela máquina ter um diâmetro maior do que
# 2,05 cm.

# %%
#----------------------------------------------
# EXEMPLO-01 
#----------------------------------------------
mu=2.0            # MÉDIA
dp=0.04           # DESVIO PADRÃO 
x=2.0             # PONTO DE CORTE (QUANTIL)

# SOLUÁCÃO DA LETRA a) AS DEMAIS b) e c) SÃO IGUAIS
norm.cdf(x,mu,dp) # USANDO NORM.CDF (precisa subtriar de 1 porque é probabilidade acumulada até x)
p=1-norm.cdf(x,mu,dp)
print("p: {:.4F}".format(p))

print("p: {:.4F}".format(norm.sf(x,mu,dp)))              # USANDO NORM.SF (Já calcula o resultado direto - acima de x)
# Out:
# p: 0.5000
# p: 0.5000

# %%
# PARA OUTROS VALORES BASTA SUBSTITUIR O VALOR DE X 
# ALTERNATIVA MAIS ELEGANTE: CRIAR UMA FUNÇÃO...

# %% [markdown]
# Exemplo-02: Considere que X é a variável aleatória que representa a nota de uma prova de Estatística de 60 alunos. Suponha que X tenha distribuição normal com média = 5,0 e desvio padrão = 1,2.
# * Calcular a probabilidade de:
# * a) Um aluno tirar nota maior do que 7,0 na prova.  Item da lista
# * b) Um aluno tirar nota maior do que 8,0 na prova.  Item da lista
# * c) Quantos alunos tiraram nota maior do que 5,0 na prova ?  Item da lista
# * d) Quantos alunos tiraram nota maior do que 6,0 na prova ?

# %%
#----------------------------------------------
# EXEMPLO-02
#----------------------------------------------
mu=5.0            # MÉDIA
dp=1.2            # DESVIO PADRÃO 
n = 60            # NÚMERO DE ALUNOS
x=5.0             # PONTO DE CORTE (QUANTIL)
norm.cdf(x,mu,dp)  
p=1-norm.cdf(x,mu,dp)         # USANDO NORM.CDF
print("p: {:.4F}".format(p)) 

print("p: {:.4F}".format(norm.sf(x,mu,dp)))  # USANDO NORM.SF
# Out:
# p: 0.5000
# p: 0.5000

# %% [markdown]
# COMO NO EXEMPLO-01
#
# * PARA OUTROS VALORES BASTA SUBSTITUIR O VALOR DE X
# * ALTERNATIVA MAIS ELEGANTE: CRIAR UMA FUNÇÃO...

# %% [markdown]
# Um parâmetro de malha de determinado tributo tem distribuição Normal com média **12** e desvio padrão **4**. Considerando que ficarão retidas em malha declarações que apresentarem o valor do parâmetro maior do que **22**, e que a população é de **10.000.000** declarantes, calcule o número de declarações retidas no atual exercício fiscal.

# %%
#----------------------------------------------
# EXEMPLO-03
#----------------------------------------------
mu=12.0           # MÉDIA
dp=4.0            # DESVIO PADRÃO 
n = 10000000      # NÚMERO DE DECLARANTES
x=22.             # PONTO DE CORTE (QUANTIL)
norm.cdf(x,mu,dp)  
p=1-norm.cdf(x,mu,dp)       # USANDO NORM.CDF
print("Probabilidade: {:.4f}".format(p))

r=p*n
print("Retidos na malha: {:.0f} declarantes".format(r))

r=norm.sf(x,mu,dp)*n        # USANDO NORM.SF 
print("Retidos na malha: {:.0f} declarantes".format(r))

# %% [markdown]
# COMO NOS EXEMPLOS: 01 - 02
# * PARA OUTROS VALORES BASTA SUBSTITUIR O VALOR DE X
# * ALTERNATIVA MAIS ELEGANTE: CRIAR UMA FUNÇÃO...
